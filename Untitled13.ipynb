# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "/Users/ashpreetsingh/Downloads/Diamonds Prices2022.csv"
#Source -- Kaggle data set : https://www.kaggle.com/datasets/nancyalaswad90/diamonds-prices

# %%
df = pd.read_csv(path)
df.set_index('Unnamed: 0')
# Out:
#             carat        cut color clarity  depth  table  price     x     y  \
# Unnamed: 0
# 1            0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2            0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3            0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4            0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5            0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53939        0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53940        0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
# 53941        0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53942        0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73
# 53943        0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
#
#                z
# Unnamed: 0
# ...

# %%
caratlist = df['carat']
pricelist = df['price']
cutlist = df['cut']
clarity = df['clarity']
depth = df['depth']

# %%
fig1 = plt.figure()
axes1 = fig1.add_axes([0.5,.5,2,2])
axes1.plot(pricelist,caratlist)
axes1.set_xlabel('Price')
axes1.set_ylabel('Carat')
axes1.set_title('Carat V/S Price')
# Out:
# Text(0.5, 1.0, 'Carat V/S Price')

# %%
fig,axes = plt.subplots(nrows=3,ncols=1,figsize=(25,25),dpi=100)
axes[0].plot(pricelist,cutlist,color='purple')
axes[0].set_xlabel('Price')
axes[0].set_ylabel('Cuts')
axes[1].plot(pricelist,clarity,lw=10,color='r',ls='--')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Clarity')
axes[2].plot(pricelist,depth,color='green')
axes[2].set_xlabel('Price')
axes[2].set_ylabel('Depth')

plt.tight_layout()

# %%
depthl = df['depth']
nfig = plt.figure()
ax1 = nfig.add_axes([1,1,2,1])
ax1.plot(pricelist,caratlist,label='B')
ax1.plot(pricelist,depthl,label='A')
nfig.legend(loc=5)
